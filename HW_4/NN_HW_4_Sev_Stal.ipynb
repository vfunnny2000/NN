# %% [markdown]
# <a href="https://colab.research.google.com/github/vfunnny2000/NN/blob/main/HW_4/NN_HW_4_Sev_Stal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense
from keras.preprocessing.image import ImageDataGenerator

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   validation_split = 0.2)

# %%
import tensorflow as tf
tf.keras.backend.clear_session()

# %%
import pandas as pd

df=pd.read_csv('/content/train (1).csv')

# %%
df.head()
# Out:
#          ImageId  ClassId                                      EncodedPixels
# 0  0002cc93b.jpg        1  29102 12 29346 24 29602 24 29858 24 30114 24 3...
# 1  0007a71bf.jpg        3  18661 28 18863 82 19091 110 19347 110 19603 11...
# 2  000a4bcdd.jpg        1  37607 3 37858 8 38108 14 38359 20 38610 25 388...
# 3  000f6bf48.jpg        4  131973 1 132228 4 132483 6 132738 8 132993 11 ...
# 4  0014fce06.jpg        3  229501 11 229741 33 229981 55 230221 77 230468...

# %%
df.loc[lambda df: df['ImageId']=='0000f269f.jpg']
# Out:
# Empty DataFrame
# Columns: [ImageId, ClassId, EncodedPixels]
# Index: []

# %%
sub=pd.read_csv('/content/sample_submission (1).csv')

# %%
sub.head()
# Out:
#          ImageId EncodedPixels  ClassId
# 0  0000f269f.jpg      1 409600        0
# 1  000ccc2ac.jpg      1 409600        0
# 2  002451917.jpg      1 409600        0
# 3  003c5da97.jpg      1 409600        0
# 4  0042e163f.jpg      1 409600        0

# %%
df['ClassId']=df['ClassId'].astype(str)

# %%
trainData = train_datagen.flow_from_dataframe(dataframe=df,
                                                directory='/content/drive/MyDrive/train_images/train_images/',
                                                target_size=(128, 128), x_col='ImageId',
                                                y_col='ClassId', batch_size=16,
                                                class_mode='categorical', subset = "training")
# Out:
# Found 28 validated image filenames belonging to 4 classes.
# /usr/local/lib/python3.10/dist-packages/keras/src/preprocessing/image.py:1137: UserWarning: Found 7060 invalid image filename(s) in x_col="ImageId". These filename(s) will be ignored.
#   warnings.warn(

# %%
validData = train_datagen.flow_from_dataframe(dataframe=df,
                                                directory='/content/drive/MyDrive/train_images/train_images/',
                                                target_size=(128, 128), x_col='ImageId',
                                                y_col='ClassId', batch_size=16,
                                                class_mode='categorical', subset = "validation")
# Out:
# Found 7 validated image filenames belonging to 4 classes.
# /usr/local/lib/python3.10/dist-packages/keras/src/preprocessing/image.py:1137: UserWarning: Found 7060 invalid image filename(s) in x_col="ImageId". These filename(s) will be ignored.
#   warnings.warn(

# %%
model = Sequential()

# %%
model.add(Conv2D(32, (3, 3), input_shape = (128, 128, 3), activation = 'relu'))
model.add(MaxPooling2D(pool_size = (2, 2)))
model.add(Conv2D(64, (3, 3),  activation = 'relu'))
model.add(MaxPooling2D(pool_size = (2, 2)))
model.add(Flatten())
model.add(Dense(units = 128, activation = 'relu'))
model.add(Dense(units = 4, activation = 'softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_2 (Conv2D)           (None, 126, 126, 32)      896
#
#  max_pooling2d_2 (MaxPoolin  (None, 63, 63, 32)        0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 61, 61, 64)        18496
#
#  max_pooling2d_3 (MaxPoolin  (None, 30, 30, 64)        0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 57600)             0
#
#  dense_2 (Dense)             (None, 128)               7372928
#
#  dense_3 (Dense)             (None, 4)                 516
#
# ...
# Total params: 7392836 (28.20 MB)
# Trainable params: 7392836 (28.20 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(loss = "categorical_crossentropy", optimizer = "adam", metrics = ["accuracy"])

# %%
model.fit(trainData, steps_per_epoch= len(trainData), epochs = 10, verbose= 1, validation_data = validData, validation_steps = len(validData))
# Out:
# Epoch 1/10
# 2/2 [==============================] - 3s 1s/step - loss: 1.9977 - accuracy: 0.5357 - val_loss: 2.4396 - val_accuracy: 0.4286
# Epoch 2/10
# 2/2 [==============================] - 1s 515ms/step - loss: 1.3896 - accuracy: 0.3571 - val_loss: 1.6652 - val_accuracy: 0.4286
# Epoch 3/10
# 2/2 [==============================] - 1s 530ms/step - loss: 1.1747 - accuracy: 0.5714 - val_loss: 1.2134 - val_accuracy: 0.2857
# Epoch 4/10
# 2/2 [==============================] - 1s 467ms/step - loss: 0.8621 - accuracy: 0.5714 - val_loss: 1.7126 - val_accuracy: 0.2857
# Epoch 5/10
# 2/2 [==============================] - 1s 448ms/step - loss: 0.8908 - accuracy: 0.6071 - val_loss: 2.1783 - val_accuracy: 0.4286
# Epoch 6/10
# 2/2 [==============================] - 1s 549ms/step - loss: 0.6715 - accuracy: 0.6429 - val_loss: 1.4591 - val_accuracy: 0.2857
# Epoch 7/10
# ...

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
import os

# %%
image_list = os.listdir('/content/drive/MyDrive/test_images/test_images')

# %%
import numpy as np

# %%
predicted_classes = []

for image_name in image_list:
    image_path = os.path.join('/content/drive/MyDrive/test_images/test_images', image_name)
    image = tf.keras.preprocessing.image.load_img(image_path, target_size=(128, 128))
    image = tf.keras.preprocessing.image.img_to_array(image)
    image = np.expand_dims(image, axis=0)
    image = tf.keras.applications.resnet50.preprocess_input(image)
    predictions = model.predict(image)
    predicted_class = np.argmax(predictions, axis=1)
    predicted_classes.append(predicted_class)
# Out:
# ...
# 1/1 [==============================] - 0s 32ms/step
# ...
# ...
# 1/1 [==============================] - 0s 47ms/step

# %%
submission=pd.DataFrame()

# %%
values=np.array(predicted_classes)

# %%
submission['ImageId']=image_list
submission['EncodedPixels']='1 409600'
submission['ClassId']=values

# %%
submission.head()
# Out:
#          ImageId EncodedPixels  ClassId
# 0  374034832.jpg      1 409600        2
# 1  37377fb0f.jpg      1 409600        0
# 2  3736d042c.jpg      1 409600        2
# 3  372e173f7.jpg      1 409600        0
# 4  372079a13.jpg      1 409600        0

# %%
submission.tail()
# Out:
#             ImageId EncodedPixels  ClassId
# 3536  a269d58e3.jpg      1 409600        0
# 3537  a273ec9d4.jpg      1 409600        0
# 3538  a28572637.jpg      1 409600        0
# 3539  a27afe1dd.jpg      1 409600        2
# 3540  a2491cf5f.jpg      1 409600        0

# %%
submission.head(30)
# Out:
#           ImageId EncodedPixels  ClassId
# 0   374034832.jpg      1 409600        2
# 1   37377fb0f.jpg      1 409600        0
# 2   3736d042c.jpg      1 409600        2
# 3   372e173f7.jpg      1 409600        0
# 4   372079a13.jpg      1 409600        0
# 5   37365bd82.jpg      1 409600        2
# 6   37319d9cc.jpg      1 409600        0
# 7   3730c15d7.jpg      1 409600        0
# 8   37368759e.jpg      1 409600        0
# 9   371bb49cf.jpg      1 409600        0
# 10  3922129e1.jpg      1 409600        0
# 11  390094957.jpg      1 409600        2
# 12  390ea6ce4.jpg      1 409600        0
# 13  38e89262f.jpg      1 409600        0
# 14  39131a7b3.jpg      1 409600        0
# 15  3925e027e.jpg      1 409600        0
# 16  38e7f6e32.jpg      1 409600        0
# 17  38b9631df.jpg      1 409600        0
# 18  38be9290e.jpg      1 409600        0
# 19  38b06680f.jpg      1 409600        0
# 20  38a11c248.jpg      1 409600        0
# 21  38561bc49.jpg      1 409600        0
# ...

# %% [markdown]
# <a href="https://colab.research.google.com/github/vfunnny2000/NN/blob/main/HW_3/lesson_3_NN_HW_1_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install keras-preprocessing

# %%
import keras_preprocessing

# %%
# !pip3 install tensorflow

# %%
import keras
from keras.layers import *
import matplotlib.pyplot as plt
import numpy as np
import keras.utils
import tensorflow
import keras.utils as image
from keras.optimizers import SGD
from keras.layers import Dropout
# from tensorflow.keras.preprocessing import image

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.fashion_mnist.load_data()

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
y_train[:20]
# Out:
# array([9, 0, 0, 3, 0, 2, 7, 2, 5, 5, 0, 9, 5, 5, 7, 9, 1, 0, 6, 4],
#       dtype=uint8)

# %%
for i in range(7):
    plt.subplot(4,7,i+1)
    plt.imshow(x_train[i])
plt.show()

# %%
input_shape = (28, 28, 1)

# %%
model_1 = keras.Sequential([
      keras.Input(shape=input_shape),
      Conv2D(32, padding = 'same', kernel_size = (3,3), activation = 'relu' ),
      MaxPooling2D( (2,2), strides = 2),
      Conv2D(64, padding = 'same', kernel_size = (3,3), activation = 'relu' ),
      MaxPooling2D( (2,2), strides = 2),
      Flatten(), # перевод в одномерный массив
      Dense(50,activation = 'relu'), # количество входных нейронов
      Dropout(0.5),  # Добавляем слой Dropout с коэффициентом 0.5
      Dense(10, activation = 'softmax')   # количество выходных нейронов
      ] )

# %%
model_1.compile(optimizer=SGD(learning_rate=0.01, momentum=0.9),  # Задаем параметры learning rate и momentum для SGD
               loss='categorical_crossentropy',
               metrics=['accuracy'])

# %%
x_train = x_train / 255
x_test = x_test / 255
y_train_cat = keras.utils.to_categorical(y_train, 10)
y_test_cat = keras.utils.to_categorical(y_test, 10)

# %%
# %%time

history = model_1.fit(x_train, y_train_cat, batch_size=32, epochs=5,validation_data =(x_test, y_test_cat) )
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 89s 47ms/step - loss: 0.7655 - accuracy: 0.7095 - val_loss: 0.4478 - val_accuracy: 0.8383
# Epoch 2/5
# 1875/1875 [==============================] - 70s 37ms/step - loss: 0.5042 - accuracy: 0.8170 - val_loss: 0.3740 - val_accuracy: 0.8609
# Epoch 3/5
# 1875/1875 [==============================] - 69s 37ms/step - loss: 0.4221 - accuracy: 0.8465 - val_loss: 0.3215 - val_accuracy: 0.8827
# Epoch 4/5
# 1875/1875 [==============================] - 70s 38ms/step - loss: 0.3827 - accuracy: 0.8608 - val_loss: 0.3034 - val_accuracy: 0.8912
# Epoch 5/5
# 1875/1875 [==============================] - 69s 37ms/step - loss: 0.3502 - accuracy: 0.8728 - val_loss: 0.2979 - val_accuracy: 0.8878
# CPU times: user 8min 14s, sys: 59.4 s, total: 9min 14s
# Wall time: 6min 23s

# %%
model_2 = keras.Sequential([
      keras.Input(shape=input_shape),
      Flatten(),
      Dense(50, activation = 'relu'),
      Dropout(0.5),
      Dense(10, activation = 'softmax')
      ] )

# %%
model_2.compile(optimizer=SGD(learning_rate=0.01, momentum=0.9),  # Задаем параметры learning rate и momentum для SGD
               loss='categorical_crossentropy',
               metrics=['accuracy'])

# %%
# %%time

history = model_2.fit(x_train, y_train_cat, batch_size=32, epochs=5,validation_data =(x_test, y_test_cat) )
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.7705 - accuracy: 0.7179 - val_loss: 0.4984 - val_accuracy: 0.8132
# Epoch 2/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.6024 - accuracy: 0.7798 - val_loss: 0.4673 - val_accuracy: 0.8344
# Epoch 3/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.5675 - accuracy: 0.7937 - val_loss: 0.4497 - val_accuracy: 0.8337
# Epoch 4/5
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.5501 - accuracy: 0.7979 - val_loss: 0.4443 - val_accuracy: 0.8385
# Epoch 5/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.5333 - accuracy: 0.8038 - val_loss: 0.4428 - val_accuracy: 0.8436
# CPU times: user 22.3 s, sys: 1.36 s, total: 23.6 s
# Wall time: 41.8 s

# %%
model_3 = keras.Sequential([
      keras.Input(shape=input_shape),
      Conv2D(32, padding = 'same', kernel_size = (3,3), activation = 'relu' ),
      MaxPooling2D( (2,2), strides = 2),
      Conv2D(64, padding = 'same', kernel_size = (3,3), activation = 'relu' ),
      MaxPooling2D( (2,2), strides = 2),
      Flatten(), # перевод в одномерный массив
      Dense(50,activation = 'relu'), # количество входных нейронов
      Dropout(0.5),
      Dense(10, activation = 'softmax')   # количество выходных нейронов
      ])

# %%
model_3.compile(optimizer=SGD(learning_rate=0.01, momentum=0.9),  # Задаем параметры learning rate и momentum для SGD
               loss='categorical_crossentropy',
               metrics=['accuracy'])

# %%
# %%time

history = model_3.fit(x_train, y_train_cat, batch_size=32, epochs=5,validation_data =(x_test, y_test_cat) )
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 69s 36ms/step - loss: 0.7592 - accuracy: 0.7136 - val_loss: 0.4334 - val_accuracy: 0.8414
# Epoch 2/5
# 1875/1875 [==============================] - 69s 37ms/step - loss: 0.4989 - accuracy: 0.8149 - val_loss: 0.3524 - val_accuracy: 0.8733
# Epoch 3/5
# 1875/1875 [==============================] - 68s 36ms/step - loss: 0.4191 - accuracy: 0.8494 - val_loss: 0.3267 - val_accuracy: 0.8799
# Epoch 4/5
# 1875/1875 [==============================] - 69s 37ms/step - loss: 0.3680 - accuracy: 0.8679 - val_loss: 0.2939 - val_accuracy: 0.8963
# Epoch 5/5
# 1875/1875 [==============================] - 67s 36ms/step - loss: 0.3425 - accuracy: 0.8770 - val_loss: 0.2833 - val_accuracy: 0.8969
# CPU times: user 8min 12s, sys: 59.7 s, total: 9min 12s
# Wall time: 6min 22s

# %%
model_4 = keras.Sequential([
      keras.Input(shape=input_shape),
      Conv2D(32, padding = 'same', kernel_size = (3,3), activation = 'relu' ),
      MaxPooling2D( (2,2), strides = 2),
      Conv2D(64, padding = 'same', kernel_size = (3,3), activation = 'relu' ),
      MaxPooling2D( (2,2), strides = 2),
      Conv2D(128, padding = 'same', kernel_size = (3,3), activation = 'relu' ),
      MaxPooling2D( (2,2), strides = 2),
      Flatten(), # перевод в одномерный массив
      Dense(128,activation = 'relu'), # количество входных нейронов
      Dropout(0.5),
      Dense(10, activation = 'softmax')   # количество выходных нейронов
      ] )

# %%
model_4.compile(optimizer=SGD(learning_rate=0.01, momentum=0.9),  # Задаем параметры learning rate и momentum для SGD
               loss='categorical_crossentropy',
               metrics=['accuracy'])

# %%
# %%time

history = model_4.fit(x_train, y_train_cat, batch_size=32, epochs=10,validation_data =(x_test, y_test_cat) )
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 97s 51ms/step - loss: 0.6738 - accuracy: 0.7477 - val_loss: 0.3870 - val_accuracy: 0.8566
# Epoch 2/10
# 1875/1875 [==============================] - 96s 51ms/step - loss: 0.3951 - accuracy: 0.8576 - val_loss: 0.3253 - val_accuracy: 0.8819
# Epoch 3/10
# 1875/1875 [==============================] - 95s 51ms/step - loss: 0.3372 - accuracy: 0.8781 - val_loss: 0.3275 - val_accuracy: 0.8779
# Epoch 4/10
# 1875/1875 [==============================] - 95s 51ms/step - loss: 0.3016 - accuracy: 0.8910 - val_loss: 0.2901 - val_accuracy: 0.8942
# Epoch 5/10
# 1875/1875 [==============================] - 95s 51ms/step - loss: 0.2790 - accuracy: 0.8971 - val_loss: 0.2745 - val_accuracy: 0.8992
# Epoch 6/10
# 1875/1875 [==============================] - 95s 51ms/step - loss: 0.2569 - accuracy: 0.9061 - val_loss: 0.2668 - val_accuracy: 0.9051
# Epoch 7/10
# 1875/1875 [==============================] - 95s 51ms/step - loss: 0.2450 - accuracy: 0.9106 - val_loss: 0.2852 - val_accuracy: 0.8951
# Epoch 8/10
# 1875/1875 [==============================] - 93s 50ms/step - loss: 0.2297 - accuracy: 0.9156 - val_loss: 0.2535 - val_accuracy: 0.9084
# Epoch 9/10
# 1875/1875 [==============================] - 95s 51ms/step - loss: 0.2191 - accuracy: 0.9204 - val_loss: 0.2516 - val_accuracy: 0.9107
# Epoch 10/10
# 1875/1875 [==============================] - 94s 50ms/step - loss: 0.2103 - accuracy: 0.9230 - val_loss: 0.2520 - val_accuracy: 0.9101
# CPU times: user 23min 56s, sys: 2min 1s, total: 25min 58s
# Wall time: 16min 22s

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Точность модели')
plt.ylabel('точность')
plt.xlabel('количество эпох')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Потери модели')
plt.ylabel('Потери')
plt.xlabel('количество эпох')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
model_4.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_11 (Conv2D)          (None, 28, 28, 32)        320
#
#  max_pooling2d_11 (MaxPooli  (None, 14, 14, 32)        0
#  ng2D)
#
#  conv2d_12 (Conv2D)          (None, 14, 14, 64)        18496
#
#  max_pooling2d_12 (MaxPooli  (None, 7, 7, 64)          0
#  ng2D)
#
#  conv2d_13 (Conv2D)          (None, 7, 7, 128)         73856
#
#  max_pooling2d_13 (MaxPooli  (None, 3, 3, 128)         0
#  ng2D)
#
#  flatten_7 (Flatten)         (None, 1152)              0
#
#  dense_14 (Dense)            (None, 128)               147584
#
#  dropout_7 (Dropout)         (None, 128)               0
#
#  dense_15 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 241546 (943.54 KB)
# Trainable params: 241546 (943.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
keras.utils.plot_model(model_4)

# %% [markdown]
# SGD (Stochastic Gradient Descent) в нейросетях используется как оптимизационный алгоритм для обучения нейронных сетей. Он работает путем итеративного обновления весов сети на основе градиента функции потерь.
#
# SGD является основным алгоритмом оптимизации в обучении нейронных сетей и широко используется в практике глубокого обучения.
#
# В общем и целом обучающая и тестовая модели показали схожие результаты, но они далеки от "идеала".
